# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# Read the CSV file
df = pd.read_csv("polynomial_data.csv")

# Plot the data
plt.figure(figsize=(10, 6))
plt.scatter(df["x_train"], df["y_train"], color="teal", label="Loaded Data", alpha=0.8)
plt.title("Loaded Polynomial Regression Data")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

print("Loaded data shape:",df.shape)
# Out:
# Loaded data shape: (140, 2)

# %%
x = df['x_train'].values.reshape(-1, 1)
y = df['y_train'].values.reshape(-1, 1)
x_mean = np.mean(x)
x_std = np.std(x)
x= (x-x_mean)/x_std
m=df.shape[0]
print(m)
w =np.array([[0],[0],[0],[0],[0],[0]])
print(w.shape)
b=0
iteration = 50000
cost =[]
alpha =0.02

degrees = 6
x_train = np.hstack([(x ** i) for i in range(1, degrees + 1)])

#below code will not give minimum cost cause this will take mean of every feature
# x_mean = np.mean(x_train, axis=0)
# print(x_mean.shape)
# x_std = np.std(x_train, axis=0)
# x_train = (x_train - x_mean) / x_std

print(x_train.shape)
for i in range(iteration):
    y_pred = x_train@w+b
    cst = (1/(2*m))*np.sum((y_pred-y)**2)
    cost.append(cst)
    w= w- alpha*(1/m)*(x_train.T@(y_pred-y))
    b = b-alpha*(1/m)*np.sum(y_pred-y)

print(w)
print(b)
plt.scatter(x, df["y_train"], color="teal", label="Loaded Data", alpha=0.8)
plt.plot(x,y_pred)
plt.show()
plt.plot(cost)
plt.show()
print(cost[-1])
# Out:
# 140
# (6, 1)
# (140, 6)
# [[ 2.30594432]
#  [-4.97487082]
#  [-1.03398309]
#  [ 2.24690562]
#  [ 0.46952964]
#  [-0.22541879]]
# 9.314017575142191
# 0.10183537969464256
